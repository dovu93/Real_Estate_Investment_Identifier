# %%
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
csvpath = Path("../Resources/Jack/Texas_Pricing_Data.csv")

# %%
pricing_data_df = pd.read_csv(csvpath)

# %%
pricing_data_df.drop('month_date_yyyymm',axis=1,inplace=True)

# %%
pricing_data_df.sort_values(by=['postal_code','month_date_yyyymm'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-ff9ccab043eb> in <module>
# ----> 1 pricing_data_df.sort_values(by=['postal_code','month_date_yyyymm'], inplace=True)
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5271             from pandas.core.sorting import lexsort_indexer
#    5272
# -> 5273             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    5274
#    5275             # need to rewrap columns in Series to apply key function
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py in <listcomp>(.0)
#    5271             from pandas.core.sorting import lexsort_indexer
#    5272
# -> 5273             keys = [self._get_label_or_level_values(x, axis=axis) for x in by]
#    5274
#    5275             # need to rewrap columns in Series to apply key function
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1558             values = self.axes[axis].get_level_values(key)._values
#    1559         else:
# -> 1560             raise KeyError(key)
#    1561
#    1562         # Check for duplicates
#
# KeyError: 'month_date_yyyymm'

# %%
pricing_data_df['pct_price_change'] = pricing_data_df['median_listing_price'].pct_change()

# %%
pricing_data_df.dropna(inplace=True)

# %%
pricing_data_df[pricing_data_df['postal_code'] == 77002].corr()
# Out:
#                                       postal_code  median_listing_price  \
# postal_code                                   NaN                   NaN
# median_listing_price                          NaN              1.000000
# active_listing_count                          NaN             -0.362083
# median_days_on_market                         NaN              0.079962
# new_listing_count                             NaN             -0.227016
# price_increased_count                         NaN                   NaN
# price_reduced_count                           NaN             -0.399622
# pending_listing_count                         NaN             -0.254997
# median_listing_price_per_square_feet          NaN              0.597835
# median_square_feet                            NaN              0.077716
# average_listing_price                         NaN              0.466510
# total_listing_count                           NaN             -0.354168
# pending_ratio                                 NaN             -0.192647
# pct_price_change                              NaN              0.445938
#
#                                       active_listing_count  \
# postal_code                                            NaN
# median_listing_price                             -0.362083
# active_listing_count                              1.000000
# median_days_on_market                            -0.303599
# new_listing_count                                 0.136614
# price_increased_count                                  NaN
# price_reduced_count                               0.424703
# pending_listing_count                             0.439929
# median_listing_price_per_square_feet             -0.233471
# median_square_feet                               -0.232045
# average_listing_price                            -0.364347
# total_listing_count                               0.802542
# pending_ratio                                     0.259542
# pct_price_change                                 -0.130160
#
#                                       median_days_on_market  \
# postal_code                                             NaN
# median_listing_price                               0.079962
# active_listing_count                              -0.303599
# median_days_on_market                              1.000000
# new_listing_count                                 -0.420711
# price_increased_count                                   NaN
# price_reduced_count                               -0.082729
# pending_listing_count                             -0.273562
# median_listing_price_per_square_feet              -0.040238
# median_square_feet                                 0.148552
# average_listing_price                              0.234604
# total_listing_count                               -0.336658
# pending_ratio                                     -0.211752
# pct_price_change                                   0.296636
#
#                                       new_listing_count  \
# postal_code                                         NaN
# median_listing_price                          -0.227016
# active_listing_count                           0.136614
# median_days_on_market                         -0.420711
# new_listing_count                              1.000000
# price_increased_count                               NaN
# price_reduced_count                            0.031116
# pending_listing_count                          0.177016
# median_listing_price_per_square_feet          -0.021564
# median_square_feet                            -0.186830
# average_listing_price                         -0.291538
# total_listing_count                            0.187309
# pending_ratio                                  0.146742
# pct_price_change                              -0.331597
#
#                                       price_increased_count  \
# postal_code                                             NaN
# median_listing_price                                    NaN
# active_listing_count                                    NaN
# median_days_on_market                                   NaN
# new_listing_count                                       NaN
# price_increased_count                                   NaN
# price_reduced_count                                     NaN
# pending_listing_count                                   NaN
# median_listing_price_per_square_feet                    NaN
# median_square_feet                                      NaN
# average_listing_price                                   NaN
# total_listing_count                                     NaN
# pending_ratio                                           NaN
# pct_price_change                                        NaN
#
#                                       price_reduced_count  \
# postal_code                                           NaN
# median_listing_price                            -0.399622
# active_listing_count                             0.424703
# median_days_on_market                           -0.082729
# new_listing_count                                0.031116
# price_increased_count                                 NaN
# price_reduced_count                              1.000000
# pending_listing_count                            0.450446
# median_listing_price_per_square_feet            -0.386785
# median_square_feet                               0.023915
# average_listing_price                           -0.189593
# total_listing_count                              0.515965
# pending_ratio                                    0.404014
# pct_price_change                                -0.048345
#
#                                       pending_listing_count  \
# postal_code                                             NaN
# median_listing_price                              -0.254997
# active_listing_count                               0.439929
# median_days_on_market                             -0.273562
# new_listing_count                                  0.177016
# price_increased_count                                   NaN
# price_reduced_count                                0.450446
# pending_listing_count                              1.000000
# median_listing_price_per_square_feet              -0.435740
# median_square_feet                                 0.350665
# average_listing_price                              0.034771
# total_listing_count                                0.888824
# pending_ratio                                      0.978566
# pct_price_change                                   0.079289
#
#                                       median_listing_price_per_square_feet  \
# postal_code                                                            NaN
# median_listing_price                                              0.597835
# active_listing_count                                             -0.233471
# median_days_on_market                                            -0.040238
# new_listing_count                                                -0.021564
# price_increased_count                                                  NaN
# price_reduced_count                                              -0.386785
# pending_listing_count                                            -0.435740
# median_listing_price_per_square_feet                              1.000000
# median_square_feet                                               -0.441390
# average_listing_price                                             0.237355
# total_listing_count                                              -0.408614
# pending_ratio                                                    -0.411334
# pct_price_change                                                  0.140847
#
#                                       median_square_feet  \
# postal_code                                          NaN
# median_listing_price                            0.077716
# active_listing_count                           -0.232045
# median_days_on_market                           0.148552
# new_listing_count                              -0.186830
# price_increased_count                                NaN
# price_reduced_count                             0.023915
# pending_listing_count                           0.350665
# median_listing_price_per_square_feet           -0.441390
# median_square_feet                              1.000000
# average_listing_price                           0.526255
# total_listing_count                             0.114551
# pending_ratio                                   0.445549
# pct_price_change                                0.184634
#
#                                       average_listing_price  \
# postal_code                                             NaN
# median_listing_price                               0.466510
# active_listing_count                              -0.364347
# median_days_on_market                              0.234604
# new_listing_count                                 -0.291538
# price_increased_count                                   NaN
# price_reduced_count                               -0.189593
# pending_listing_count                              0.034771
# median_listing_price_per_square_feet               0.237355
# median_square_feet                                 0.526255
# average_listing_price                              1.000000
# total_listing_count                               -0.162820
# pending_ratio                                      0.137889
# pct_price_change                                   0.315522
#
#                                       total_listing_count  pending_ratio  \
# postal_code                                           NaN            NaN
# median_listing_price                            -0.354168      -0.192647
# active_listing_count                             0.802542       0.259542
# median_days_on_market                           -0.336658      -0.211752
# new_listing_count                                0.187309       0.146742
# price_increased_count                                 NaN            NaN
# price_reduced_count                              0.515965       0.404014
# pending_listing_count                            0.888824       0.978566
# median_listing_price_per_square_feet            -0.408614      -0.411334
# median_square_feet                               0.114551       0.445549
# average_listing_price                           -0.162820       0.137889
# total_listing_count                              1.000000       0.782536
# pending_ratio                                    0.782536       1.000000
# pct_price_change                                -0.013744       0.115246
#
#                                       pct_price_change
# postal_code                                        NaN
# median_listing_price                          0.445938
# active_listing_count                         -0.130160
# median_days_on_market                         0.296636
# new_listing_count                            -0.331597
# price_increased_count                              NaN
# price_reduced_count                          -0.048345
# pending_listing_count                         0.079289
# median_listing_price_per_square_feet          0.140847
# median_square_feet                            0.184634
# average_listing_price                         0.315522
# total_listing_count                          -0.013744
# pending_ratio                                 0.115246
# pct_price_change                              1.000000

# %%
ax1 = pricing_data_df[pricing_data_df['postal_code'] == 77002].plot(kind='scatter', x='active_listing_count', y='pct_price_change', color='blue', alpha=0.5, figsize=(10, 7))
plt.legend(labels=[77002])
plt.title('Relationship between Activing Listing Count and PCT Change in 77002', size=24)
plt.xlabel('Activing Listing Count', size=18)
plt.ylabel('PCT Change', size=18);

# %%
mlr_zip = LinearRegression()

# %%
mlr_zip.fit(df_zip[['median_listing_price','new_listing_count']], df_zip['pct_price_change'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-97d0b122911b> in <module>
# ----> 1 mlr_zip.fit(df_zip[['median_listing_price','new_listing_count']], df_zip['pct_price_change'])
#
# NameError: name 'df_zip' is not defined

# %%
print(mlr_zip.intercept_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-14b1ae4fe0c8> in <module>
# ----> 1 print(mlr_zip.intercept_)
#
# AttributeError: 'LinearRegression' object has no attribute 'intercept_'

# %%
print(mlr_zip.coef_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-9f7b515b20ab> in <module>
# ----> 1 print(mlr_zip.coef_)
#
# AttributeError: 'LinearRegression' object has no attribute 'coef_'
