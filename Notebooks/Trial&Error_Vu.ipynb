# %%
from dotenv import load_dotenv
import os
import requests
import json
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
api_key = os.getenv("ZIPCODE_API_KEY")
type(api_key)
# We could potentially make this interactive in the future.
zip_code = 77002
distance = 5
units = "miles"

# %%
url = f"http://www.zipcodeapi.com/rest/{api_key}/radius.json/{zip_code}/{distance}/{units}"

# %%
response_data = requests.get(url)
data = response_data.json()
print(json.dumps(data, indent=4))
# Out:
# {
#     "zip_codes": [
#         {
#             "zip_code": "77021",
#             "distance": 4.071,
#             "city": "Houston",
#             "state": "TX"
#         },
#         {
#             "zip_code": "77030",
#             "distance": 4.082,
#             "city": "Houston",
#             "state": "TX"
#         },
#         {
#             "zip_code": "77005",
#             "distance": 4.396,
#             "city": "Houston",
#             "state": "TX"
#         },
#         {
#             "zip_code": "77023",
#             "distance": 3.714,
#             "city": "Houston",
#             "state": "TX"
#         },
#         {
#             "zip_code": "77004",
#             "distance": 2.211,
#             "city": "Houston",
#             "state": "TX"
#         },
#         {
#             "zip_code": "77046",
#             "distance": 4.39,
#             "city": "Houston",
#             "state": "TX"
#         },
#         {
#             "zip_code": "77098",
# ...

# %%
zip_codes = []
city = []

for line in data["zip_codes"]:

    new_zip_code = int(line["zip_code"])
    zip_codes.append(new_zip_code)
    
    new_city = line["city"]
    city.append(new_city)

# %%
zip_code_df = pd.DataFrame()
zip_code_df['Zip Code']  = zip_codes
zip_code_df['City']  = city

# %%
zip_code_df.set_index("Zip Codes", inplace = True)
# zip_code_df.reset_index(inplace = True)
zip_code_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-504-5803bc08438d> in <module>
# ----> 1 zip_code_df.set_index("Zip Codes", inplace = True)
#       2 # zip_code_df.reset_index(inplace = True)
#       3 zip_code_df
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Zip Codes'] are in the columns"

# %%
zip_code_df.reset_index(inplace= True)
zip_code_df.head()
zip_code_df.rename(columns = {"Zip Codes" : "Zip Code"}, inplace = True)

# %%
zip_code_df
# Out:
#      Zip Code     City
# 0       77021  Houston
# 1       77030  Houston
# 2       77005  Houston
# 3       77023  Houston
# 4       77004  Houston
# ..        ...      ...
# 101     77007  Houston
# 102     77020  Houston
# 103     77009  Houston
# 104     77008  Houston
# 105     77026  Houston
#
# [106 rows x 2 columns]

# %%
import datetime as dt
from pathlib import Path

# %%
April_12_2018_Permit = Path("../resources/Vu/Permit_Data/2017/Apr_10_2017_Permits.csv")
permit = pd.read_csv(April_12_2018_Permit)
permit.set_index("Zip Code", inplace = True)
permit.reset_index(inplace = True)
permit.rename(columns = {"Zip Code": "Zip_Code"})
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-3b93fe3cdff7> in <module>
#       1 April_12_2018_Permit = Path("../resources/Vu/Permit_Data/2017/Apr_10_2017_Permits.csv")
# ----> 2 permit = pd.read_csv(April_12_2018_Permit)
#       3 permit.set_index("Zip Code", inplace = True)
#       4 permit.reset_index(inplace = True)
#       5 permit.rename(columns = {"Zip Code": "Zip_Code"})
#
# ...

# %%
# new_datafile = pd.concat([permit, zip_code_df], join = "inner", axis = "columns")

# %%
permit

# %%
# for line in permit:
#     x = int(line["Zip_Code"])
#     print(x)
#     print(permit["Zip Code"])
# #     print("\n")
#     condintional_variable = int(line["Zip Code"])
#     if condintional_variable in zip_codes:
# #         new_variable = int(permit["Zip Code"])
#         print(line["Zip Code"])
#     else:
#         print("this will not be included.")


# permit["Zip Code"][0]
new_df = pd.DataFrame()
count = 0
for line in permit:
    variable = permit["Zip Code"][count]
    count +=1
    if variable in zip_codes:
        new_df = new_df.append(permit.iloc[count])
#         new_df.append(permit.iloc[count])
        
        
        
        
# def check_if_zip_in(a,b,c,d):
#     count = 0
#     for line in c:
#         variable = permit["Zip Code"][count]
#         count += 1
#         if variable in a:
#             c.append
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-c76ef0032e5a> in <module>
#      15 new_df = pd.DataFrame()
#      16 count = 0
# ---> 17 for line in permit:
#      18     variable = permit["Zip Code"][count]
#      19     count +=1
#
# NameError: name 'permit' is not defined

# %%
new_df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def checking_zip(zip_code_list, datafile, new_data_file):
    count = 0
    for line in datafile:
        variable = datafile["Zip_Code"][count]
        count += 1
        if variable in zip_code_list:
            new_data_file = new_data_file.append(datafile.iloc[count])
    new_data_file = new_data_file        
    return new_data_file

# %%
new_df = pd.DataFrame()
checking_zip(zip_codes, tax_2011, new_df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
new_df
# Out:
#    Count       Date                                           Land Use  \
# 1    1.0  4/10/2017                                       Unrestricted
# 2    1.0  4/10/2017                                       Unrestricted
# 3    1.0  4/10/2017  Drainage or Detention; Landscape or Open Space...
# 4    1.0  4/10/2017                                       Unrestricted
#
#    Zip Code
# 1   77060.0
# 2   77407.0
# 3   77407.0
# 4   77017.0

# %%
new_df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip_Code", inplace = True)
tax_2011.dropna(inplace=True)

# %%
tax_2011.reset_index(inplace = True)
tax_2011.head()
# Out:
#    Zip_Code Size of adjusted gross income  Number of returns  \
# 0   75001.0              $1 under $25,000             2644.0
# 1   75001.0         $25,000 under $50,000             2442.0
# 2   75001.0         $50,000 under $75,000             1426.0
# 3   75001.0        $75,000 under $100,000              720.0
# 4   75001.0       $100,000 under $200,000              938.0
#
#    Real estate taxes  Mortgage interest paid  Total Charitable Contributions  \
# 0              562.0                   729.0                           254.0
# 1              812.0                  1223.0                           668.0
# 2             1264.0                  2460.0                          1003.0
# 3             1139.0                  1757.0                           837.0
# 4             2903.0                  4518.0                          2176.0
#
#    Taxable income  Income tax  Year
# 0          9908.0       831.0  2011
# 1         56677.0      6578.0  2011
# ...

# %%
tax_2011 = tax_2011.astype({'Zip_Code': 'int'})
dataframe call column name = 2013-01-01
pd to datetime

# %%
new_tax_2011 = pd.DataFrame()
new_tax_2011 = checking_zip(zip_codes, tax_2011, new_tax_2011) 
pd.to_datetime(2013-01-01)

# %%
new_tax_2011.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cleaned_tax_2011 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011.csv")
tax_2011.to_csv(cleaned_tax_2011, index=False, header=True)

# %%
tax_2011['date'] = pd.to_datetime('2013-01-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)

# %%
tax_2011
# Out:
#       Zip_Code Size of adjusted gross income  Number of returns  \
# 0        75001              $1 under $25,000             2644.0
# 1        75001         $25,000 under $50,000             2442.0
# 2        75001         $50,000 under $75,000             1426.0
# 3        75001        $75,000 under $100,000              720.0
# 4        75001       $100,000 under $200,000              938.0
# ...        ...                           ...                ...
# 9745     99999         $25,000 under $50,000            80393.0
# 9746     99999         $50,000 under $75,000            37097.0
# 9747     99999        $75,000 under $100,000            20967.0
# 9748     99999       $100,000 under $200,000            26310.0
# 9749     99999              $200,000 or more            13418.0
#
#       Real estate taxes  Mortgage interest paid  \
# 0                 562.0                   729.0
# 1                 812.0                  1223.0
# 2                1264.0                  2460.0
# ...

# %%
type(tax_2011["Zip_Code"][0])
# Out:
# numpy.int32

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-01-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_01 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_01.csv")
tax_2011.to_csv(cleaned_tax_2011_01, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-02-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_02 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_02.csv")
tax_2011.to_csv(cleaned_tax_2011_02, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-03-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_03 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_03.csv")
tax_2011.to_csv(cleaned_tax_2011_03, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-04-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_04 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_04.csv")
tax_2011.to_csv(cleaned_tax_2011_04, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-05-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_05 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_05.csv")
tax_2011.to_csv(cleaned_tax_2011_05, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-06-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_06 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_06.csv")
tax_2011.to_csv(cleaned_tax_2011_06, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-07-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_07 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_07.csv")
tax_2011.to_csv(cleaned_tax_2011_07, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-08-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_08 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_08.csv")
tax_2011.to_csv(cleaned_tax_2011_08, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-09-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_09 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_09.csv")
tax_2011.to_csv(cleaned_tax_2011_09, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-10-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_10 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_10.csv")
tax_2011.to_csv(cleaned_tax_2011_10, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-11-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_11 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_11.csv")
tax_2011.to_csv(cleaned_tax_2011_11, index=True, header=True)

# %%
tax_path_2011 = Path("../resources/Vu/Tax_Data/2011_Taxes.csv")
tax_2011 = pd.read_csv(tax_path_2011)
tax_2011.set_index("Zip Code", inplace = True)
tax_2011.dropna(inplace=True)
tax_2011['date'] = pd.to_datetime('2011-12-01', format='%Y-%m-%d')
tax_2011.drop("Year", axis = 1,inplace = True)
cleaned_tax_2011_12 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_12.csv")
tax_2011.to_csv(cleaned_tax_2011_12, index=True, header=True)

# %%
tax_path_1 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_01.csv")
tax_path_2 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_02.csv")
tax_path_3 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_03.csv")
tax_path_4 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_04.csv")
tax_path_5 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_05.csv")
tax_path_6 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_06.csv")
tax_path_7 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_07.csv")
tax_path_8 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_08.csv")
tax_path_9 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_09.csv")
tax_path_10 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_10.csv")
tax_path_11 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_11.csv")
tax_path_12 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011_12.csv")
tax_1 = pd.read_csv(tax_path_1)
tax_2 = pd.read_csv(tax_path_2)
tax_3 = pd.read_csv(tax_path_3)
tax_4 = pd.read_csv(tax_path_4)
tax_5 = pd.read_csv(tax_path_5)
tax_6 = pd.read_csv(tax_path_6)
tax_7 = pd.read_csv(tax_path_7)
tax_8 = pd.read_csv(tax_path_8)
tax_9 = pd.read_csv(tax_path_9)
tax_10 = pd.read_csv(tax_path_10)
tax_11 = pd.read_csv(tax_path_11)
tax_12 = pd.read_csv(tax_path_12)
tax_2011 = pd.concat([tax_1, tax_2, tax_3, tax_4, tax_5, tax_6, tax_7, tax_8, tax_9, tax_10, tax_11, tax_12], join = 'inner', axis = 'rows')

# %%
cleaned_tax_2014 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011.csv")
tax_2011.to_csv(cleaned_tax_2014, index=False, header=True)

# %%
tax2011 = Path("../resources/Vu/Tax_Data/cleaned_tax_2011.csv")
tax2012 = Path("../resources/Vu/Tax_Data/cleaned_tax_2012.csv")
tax2013 = Path("../resources/Vu/Tax_Data/cleaned_tax_2013.csv")
tax2014 = Path("../resources/Vu/Tax_Data/cleaned_tax_2014.csv")
tax2015 = Path("../resources/Vu/Tax_Data/cleaned_tax_2015.csv")
tax2016 = Path("../resources/Vu/Tax_Data/cleaned_tax_2016.csv")
tax2017 = Path("../resources/Vu/Tax_Data/cleaned_tax_2017.csv")
tax_1 = pd.read_csv(tax2011)
tax_2 = pd.read_csv(tax2012)
tax_3 = pd.read_csv(tax2013)
tax_4 = pd.read_csv(tax2014)
tax_5 = pd.read_csv(tax2015)
tax_6 = pd.read_csv(tax2016)
tax_7 = pd.read_csv(tax2017)
tax_2011 = pd.concat([tax_1, tax_2, tax_3, tax_4, tax_5, tax_6, tax_7], join = 'inner', axis = 'rows')
cleaned_tax_2014 = Path("../resources/Vu/Tax_Data/cleaned_tax_FINAL.csv")
tax_2011.to_csv(cleaned_tax_2014, index=False, header=True)

# %%
clean_path = Path("../resources/Vu/Tax_Data/cleaned_tax_FINAL.csv")

# %%
clean_tax = pd.read_csv(clean_path)
# Out:
# C:\Users\dovu9\anaconda3\envs\dev\lib\site-packages\IPython\core\interactiveshell.py:3072: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
clean_tax.tail()
# Out:
#         Zip Code Size of adjusted gross income Number of returns Real Estates  \
# 817555     99999         $25,000 under $50,000             61630        19851
# 817556     99999         $50,000 under $75,000             34030        27620
# 817557     99999        $75,000 under $100,000             20550        29631
# 817558     99999       $100,000 under $200,000             30340       102858
# 817559     99999              $200,000 or more             15790       165349
#
#        Mortgage Charity Taxable income   Income tax        date
# 817555    20496   26165    1.08887e+06       113817  2017-12-01
# 817556    29393   32531    1.33498e+06       172089  2017-12-01
# 817557    30741   31073    1.24693e+06       177819  2017-12-01
# 817558   104586   93449    3.16112e+06       541579  2017-12-01
# 817559    99481  273961    9.15648e+06  2.42239e+06  2017-12-01

# %%
type(clean_tax["Zip Code"][0])
# Out:
# numpy.int32

# %%
clean_tax = clean_tax.astype({'Zip Code': 'int'})

# %%
zip_codes
# Out:
# [77578,
#  77546,
#  77459,
#  77545,
#  77584,
#  77588,
#  77581,
#  77062,
#  77053,
#  77089,
#  77489,
#  77487,
#  77496,
#  77047,
#  77059,
#  77048,
#  77034,
#  77497,
#  77478,
#  77075,
#  77085,
#  77477,
#  77045,
#  77246,
#  77247,
#  77498,
#  77505,
#  77061,
#  77504,
#  77071,
#  77031,
#  77035,
#  77051,
#  77501,
#  77508,
#  77587,
#  77033,
#  77286,
#  77260,
#  77099,
#  77096,
#  77502,
#  77054,
#  77025,
#  77087,
#  77074,
#  77571,
#  77017,
#  77083,
#  77021,
#  77536,
#  77072,
#  77411,
#  77250,
#  77402,
#  77036,
#  77503,
#  77401,
#  77030,
#  77081,
#  77506,
#  77005,
#  77012,
#  77023,
#  77082,
#  77004,
#  77046,
#  77098,
#  77547,
#  77063,
#  77027,
#  77006,
#  77042,
#  77011,
#  77057,
#  77056,
#  77003,
#  77276,
#  77285,
#  77077,
#  77010,
#  77019,
#  77002,
#  77029,
#  77278,
#  77001,
#  77052,
#  77202,
#  77203,
#  77204,
#  77205,
#  77206,
#  77207,
#  77208,
#  77209,
#  77210,
#  77212,
#  77213,
#  77215,
#  77216,
# ...

# %%
new_df = pd.DataFrame()
count = 0
for line in clean_tax:
    variable = clean_tax["Zip Code"][count]
    count +=1
    if variable in zip_codes:
        new_df = new_df.append(clean_tax.iloc[count])

# %%
clean_tax = clean_tax.astype({'Zip Code': 'int64'})
# clean_tax = clean_tax.astype({'Number of returns': 'int64'})
# clean_tax = clean_tax.astype({'Real Estates': 'int64'})
# clean_tax = clean_tax.astype({'Mortgage': 'int64'})
# clean_tax = clean_tax.astype({'Charity': 'int64'})
# clean_tax = clean_tax.astype({'Taxable income': 'int64'})
# clean_tax = clean_tax.astype({'Income tax': 'int64'})

# %%
clean_tax
# Out:
#         Zip Code Size of adjusted gross income Number of returns Real Estates  \
# 0          75001              $1 under $25,000              2644          562
# 1          75001         $25,000 under $50,000              2442          812
# 2          75001         $50,000 under $75,000              1426         1264
# 3          75001        $75,000 under $100,000               720         1139
# 4          75001       $100,000 under $200,000               938         2903
# ...          ...                           ...               ...          ...
# 817555     99999         $25,000 under $50,000             61630        19851
# 817556     99999         $50,000 under $75,000             34030        27620
# 817557     99999        $75,000 under $100,000             20550        29631
# 817558     99999       $100,000 under $200,000             30340       102858
# 817559     99999              $200,000 or more             15790       165349
#
# ...

# %%
clean_tax.drop(columns = "Size of adjusted gross income", inplace = True)

# %%
clean_tax = clean_tax.astype({"Number of returns" : 'int64'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-526-a16fce1a6b3a> in <module>
# ----> 1 clean_tax = clean_tax.astype({"Number of returns" : 'int64'})
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5681                 if col_name in dtype:
#    5682                     results.append(
# -> 5683                         col.astype(dtype=dtype[col_name], copy=copy, errors=errors)
#    5684                     )
#    5685                 else:
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ...

# %%
type(zipp[0])
permits_df = permits_df.astype({'zip_code': 'int64'})
# Out:
# int

# %%
new_df = pd.merge(zip_code_df,clean_tax,on='Zip Code')

# %%
type(clean_tax["Taxable income"][2])
# Out:
# float

# %%
a = clean_tax["Income tax"].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-537-0541b99ec4d0> in <module>
# ----> 1 a = clean_tax["Income tax"].sum()
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\generic.py in stat_func(self, axis, skipna, level, numeric_only, min_count, **kwargs)
#   11180             skipna=skipna,
#   11181             numeric_only=numeric_only,
# > 11182             min_count=min_count,
#   11183         )
#   11184
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    3889                 )
#    3890             with np.errstate(all="ignore"):
# -> 3891                 return op(delegate, skipna=skipna, **kwds)
#    3892
#    3893         # TODO(EA) dispatch to Index
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
# ...

# %%
clean_path = Path("../resources/dan/Permit_Data/permit_data.csv")

# %%
new = pd.pivot_table(clean_tax, index = "date", values = "Number of returns", columns = "Zip Code")
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-512-d032f300ffae> in <module>
# ----> 1 new = pd.pivot_table(new_df, index = "date", values = "Number of returns", columns = "Zip Code")
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\reshape\pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      99
#     100     grouped = data.groupby(keys, observed=observed)
# --> 101     agged = grouped.agg(aggfunc)
#     102     if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     103         agged = agged.dropna(how="all")
#
# ~\anaconda3\envs\dev\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func, *args, **kwargs)
#     926         func = _maybe_mangle_lambdas(func)
#     927
# --> 928         result, how = self._aggregate(func, *args, **kwargs)
# ...
