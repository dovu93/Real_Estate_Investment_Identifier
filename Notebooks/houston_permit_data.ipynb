# %%
import pandas as pd
from pathlib import Path

# %%
# Read in the construction permits data
permits_filepath = Path("../resources/dan/Permit_Data/permit_data.csv")

permits_df = pd.read_csv(permits_filepath)

# %%
# spot check permits_df data
permits_df.head()
# Out:
#    zip_code                                           land_use  count  \
# 0   77091.0       Single Family Residential (Shared Driveways)      1
# 1   77091.0       Single Family Residential (Shared Driveways)      1
# 2   77072.0                                       Unrestricted      1
# 3   77048.0  Drainage or Detention; Landscape or Open Space...      1
# 4   77045.0              Unrestricted Intended for Multifamily      1
#
#         date   permit_type
# 0  1/23/2020   Residential
# 1  1/23/2020   Residential
# 2  1/23/2020  Unrestricted
# 3  1/23/2020   Residential
# 4  1/23/2020  Unrestricted

# %%
# check data field counts
permits_df.count()
# Out:
# zip_code       8847
# land_use       8859
# count          8859
# date           8859
# permit_type    8859
# dtype: int64

# %%
# drop rows with nulls
permits_df.dropna(inplace=True)

# repeat spot check of data field counts
permits_df.count()
# Out:
# zip_code       8847
# land_use       8847
# count          8847
# date           8847
# permit_type    8847
# dtype: int64

# %%
# check dtypes
permits_df.dtypes
# Out:
# zip_code       float64
# land_use        object
# count            int64
# date            object
# permit_type     object
# dtype: object

# %%
# check zip_code to int
permits_df = permits_df.astype({'zip_code': 'int64'})

# recheck dtypes
permits_df.dtypes
# Out:
# zip_code        int64
# land_use       object
# count           int64
# date           object
# permit_type    object
# dtype: object

# %%
# spot check permits_df data again
permits_df.head()
# Out:
#    zip_code                                           land_use  count  \
# 0     77091       Single Family Residential (Shared Driveways)      1
# 1     77091       Single Family Residential (Shared Driveways)      1
# 2     77072                                       Unrestricted      1
# 3     77048  Drainage or Detention; Landscape or Open Space...      1
# 4     77045              Unrestricted Intended for Multifamily      1
#
#         date   permit_type
# 0  1/23/2020   Residential
# 1  1/23/2020   Residential
# 2  1/23/2020  Unrestricted
# 3  1/23/2020   Residential
# 4  1/23/2020  Unrestricted

# %%
# set index to date with format of year and month
permits_df.set_index(pd.to_datetime(permits_df['date'], format='%Y%m', infer_datetime_format=True), inplace=True)

# drop non-index date column
permits_df.drop('date', axis=1, inplace=True)

# preview data
permits_df.head()
# Out:
#             zip_code                                           land_use  \
# date
# 2020-01-23     77091       Single Family Residential (Shared Driveways)
# 2020-01-23     77091       Single Family Residential (Shared Driveways)
# 2020-01-23     77072                                       Unrestricted
# 2020-01-23     77048  Drainage or Detention; Landscape or Open Space...
# 2020-01-23     77045              Unrestricted Intended for Multifamily
#
#             count   permit_type
# date
# 2020-01-23      1   Residential
# 2020-01-23      1   Residential
# 2020-01-23      1  Unrestricted
# 2020-01-23      1   Residential
# 2020-01-23      1  Unrestricted

# %%
# sort by date (index), oldest to newest, then by zip, lowest to highest
permits_df = permits_df.sort_values(by=['date','zip_code'])

# preview_data
permits_df.head(15)
# Out:
#             zip_code                                      land_use  count  \
# date
# 2017-01-05     77002                                  Unrestricted      1
# 2017-01-05     77004  Single Family Residential (Shared Driveways)      1
# 2017-01-05     77004                                  Unrestricted      1
# 2017-01-05     77004     Single Family Residential (Public Street)      1
# 2017-01-05     77006     Single Family Residential (Public Street)      1
# 2017-01-05     77006     Single Family Residential (Public Street)      1
# 2017-01-05     77006                                    Commercial      1
# 2017-01-05     77007                                  Unrestricted      1
# 2017-01-05     77007  Single Family Residential (Shared Driveways)      1
# 2017-01-05     77007                                  Unrestricted      1
# 2017-01-05     77007                                  Unrestricted      1
# 2017-01-05     77008                                  Unrestricted      1
# 2017-01-05     77008                                    Commercial      1
# 2017-01-05     77008                                    Commercial      1
# 2017-01-05     77008                                  Unrestricted      1
#
#              permit_type
# date
# 2017-01-05  Unrestricted
# 2017-01-05   Residential
# 2017-01-05  Unrestricted
# 2017-01-05   Residential
# 2017-01-05   Residential
# 2017-01-05   Residential
# 2017-01-05    Commercial
# 2017-01-05  Unrestricted
# 2017-01-05   Residential
# 2017-01-05  Unrestricted
# 2017-01-05  Unrestricted
# 2017-01-05  Unrestricted
# 2017-01-05    Commercial
# 2017-01-05    Commercial
# 2017-01-05  Unrestricted

# %%
# reorder columns for visibility to most pertinent data
permits_df = permits_df[['zip_code', 'permit_type', 'count', 'land_use']]

# preview new column order
permits_df.columns.values
# Out:
# array(['zip_code', 'permit_type', 'count', 'land_use'], dtype=object)

# %%
# preview permits_df data
permits_df.head()
# Out:
#             zip_code   permit_type  count  \
# date
# 2017-01-05     77002  Unrestricted      1
# 2017-01-05     77004   Residential      1
# 2017-01-05     77004  Unrestricted      1
# 2017-01-05     77004   Residential      1
# 2017-01-05     77006   Residential      1
#
#                                                 land_use
# date
# 2017-01-05                                  Unrestricted
# 2017-01-05  Single Family Residential (Shared Driveways)
# 2017-01-05                                  Unrestricted
# 2017-01-05     Single Family Residential (Public Street)
# 2017-01-05     Single Family Residential (Public Street)

# %%
# groupby zip_code and date and sum each zip column of permit counts
permit_counts = permits_df.groupby(["zip_code", "date"]).sum()
#permit_counts.head()

#pivot so index is date, columns are zip, and values for each are permit counts
permits_by_zip = pd.pivot_table(permit_counts, index = "date", values = "count", columns = "zip_code")

#preview dataframe
permits_by_zip.head()
# Out:
# zip_code    77002  77003  77004  77005  77006  77007  77008  77009  77010  \
# date
# 2017-01-05    1.0    NaN    3.0    NaN    3.0    4.0    7.0    NaN    NaN
# 2017-01-19    1.0    NaN    8.0    NaN    1.0    8.0    3.0    1.0    NaN
# 2017-02-02    1.0    NaN    6.0    NaN    1.0    1.0    NaN    NaN    NaN
# 2017-02-16    NaN    2.0    3.0    NaN    NaN    3.0    2.0    1.0    NaN
# 2017-03-13    1.0    2.0    3.0    NaN    1.0    3.0    5.0    2.0    NaN
#
# zip_code    77011  ...  77484  77489  77493  77494  77498  77530  77532  \
# date               ...
# 2017-01-05    NaN  ...    1.0    NaN    7.0    NaN    2.0    NaN    NaN
# 2017-01-19    NaN  ...    NaN    NaN    8.0    1.0    2.0    NaN    NaN
# 2017-02-02    NaN  ...    NaN    NaN    4.0    1.0    1.0    2.0    5.0
# 2017-02-16    NaN  ...    1.0    NaN    3.0    NaN    1.0    NaN    NaN
# 2017-03-13    2.0  ...    1.0    NaN    2.0    1.0    1.0    1.0    NaN
#
# zip_code    77545  77546  77598
# date
# 2017-01-05    2.0    NaN    NaN
# 2017-01-19    1.0    1.0    NaN
# 2017-02-02    1.0    1.0    1.0
# 2017-02-16    NaN    NaN    NaN
# 2017-03-13    1.0    NaN    NaN
#
# [5 rows x 133 columns]

# %%
#consolidate index of weekly data into year-month and sum per month
permits_by_zip.groupby([permits_by_zip.index.year, permits_by_zip.index.month]).sum()

# reset multi-index (year and month) to a year-month single index format
permits_by_zip.index = permits_by_zip.index.to_period('M')


# preview dataframe
permits_by_zip.head()
# Out:
# zip_code  77002  77003  77004  77005  77006  77007  77008  77009  77010  \
# date
# 2017-01     1.0    NaN    3.0    NaN    3.0    4.0    7.0    NaN    NaN
# 2017-01     1.0    NaN    8.0    NaN    1.0    8.0    3.0    1.0    NaN
# 2017-02     1.0    NaN    6.0    NaN    1.0    1.0    NaN    NaN    NaN
# 2017-02     NaN    2.0    3.0    NaN    NaN    3.0    2.0    1.0    NaN
# 2017-03     1.0    2.0    3.0    NaN    1.0    3.0    5.0    2.0    NaN
#
# zip_code  77011  ...  77484  77489  77493  77494  77498  77530  77532  77545  \
# date             ...
# 2017-01     NaN  ...    1.0    NaN    7.0    NaN    2.0    NaN    NaN    2.0
# 2017-01     NaN  ...    NaN    NaN    8.0    1.0    2.0    NaN    NaN    1.0
# 2017-02     NaN  ...    NaN    NaN    4.0    1.0    1.0    2.0    5.0    1.0
# 2017-02     NaN  ...    1.0    NaN    3.0    NaN    1.0    NaN    NaN    NaN
# 2017-03     2.0  ...    1.0    NaN    2.0    1.0    1.0    1.0    NaN    1.0
#
# zip_code  77546  77598
# date
# 2017-01     NaN    NaN
# 2017-01     1.0    NaN
# 2017-02     1.0    1.0
# 2017-02     NaN    NaN
# 2017-03     NaN    NaN
#
# [5 rows x 133 columns]

# %%
# clean up data: fill NaN with 0
permits_by_zip.fillna(0, inplace=True)

# clean up data: change values to intefet (from float)
permits_by_zip = permits_by_zip.astype(int)

# preview dataframe
permits_by_zip.head()
# Out:
# zip_code  77002  77003  77004  77005  77006  77007  77008  77009  77010  \
# date
# 2017-01       1      0      3      0      3      4      7      0      0
# 2017-01       1      0      8      0      1      8      3      1      0
# 2017-02       1      0      6      0      1      1      0      0      0
# 2017-02       0      2      3      0      0      3      2      1      0
# 2017-03       1      2      3      0      1      3      5      2      0
#
# zip_code  77011  ...  77484  77489  77493  77494  77498  77530  77532  77545  \
# date             ...
# 2017-01       0  ...      1      0      7      0      2      0      0      2
# 2017-01       0  ...      0      0      8      1      2      0      0      1
# 2017-02       0  ...      0      0      4      1      1      2      5      1
# 2017-02       0  ...      1      0      3      0      1      0      0      0
# 2017-03       2  ...      1      0      2      1      1      1      0      1
#
# zip_code  77546  77598
# date
# 2017-01       0      0
# 2017-01       1      0
# 2017-02       1      1
# 2017-02       0      0
# 2017-03       0      0
#
# [5 rows x 133 columns]

# %%
# # save out cleansed construction permit data
# cleaned_permits_filepath = Path("../resources/dan/Permit_Data/permits_by_zip_cleaned.csv")

# # write dataframe to csv with index (keep date) and header info
# permits_by_zip.to_csv(cleaned_permits_filepath, index=True, header=True)
